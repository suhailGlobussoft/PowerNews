# %%
from dotenv import dotenv_values
configs = dotenv_values(".config")

# %%
rss_urls = {
    # India
    "The Hindu": "https://www.thehindu.com/feeder/default.rss",
    "NDTV": "https://feeds.feedburner.com/ndtvnews-top-stories",
    "Times of India": "https://timesofindia.indiatimes.com/rssfeedstopstories.cms",
    "Hindustan Times": "https://www.hindustantimes.com/feeds/rss/web-stories/trending/rssfeed.xml",
    "The Economic Times": "https://economictimes.indiatimes.com/rssfeedstopstories.cms",
    "Business Standard": "https://www.business-standard.com/rss/",
    "Mint": "https://www.livemint.com/rss/AI",
    "MediaNama": "https://medianama.com/feed/",
    "Inc42": "https://inc42.com/feed/",
    "ESPN Cricinfo (Cricket)": "https://www.espncricinfo.com/rss/feeds/home.xml",
    "The Indian Express (Sports)": "https://indianexpress.com/section/sports/rss/",
    # International
    "The Guardian": "https://www.theguardian.com/rss",
    "The Wall Street Journal": "https://www.wsj.com/xml/rss/article/WSJnews-world.xml",
    "Bloomberg": "https://www.bloomberg.com/feeds/news",
    "Financial Times": "https://www.ft.com/rss/world-news",
    "The Verge": "https://www.theverge.com/rss",
    "Engadget": "https://www.engadget.com/rss.xml",
    "Science Magazine": "https://www.sciencemag.org/rss",
    "National Geographic": "https://www.nationalgeographic.com/news/rss",
    "Scientific American": "https://www.scientificamerican.com/rss/feed",
    'BBC': 'http://feeds.bbci.co.uk/news/rss.xml',
    'CNN': 'http://rss.cnn.com/rss/cnn_topstories.rss',
    'Al Jazeera': 'https://www.aljazeera.com/xml/rss/all.xml',
    "BBC News": "https://feeds.bbci.co.uk/news/rss.xml",
    "CNN Top Stories": "http://rss.cnn.com/rss/cnn_topstories.rss",
    "Reuters World News": "http://feeds.reuters.com/reuters/worldNews",
    "NY Times World News": "https://rss.nytimes.com/services/xml/rss/nyt/World.xml",
    "TechCrunch": "http://feeds.feedburner.com/TechCrunch/",
    "Google News (Technology)": "https://news.google.com/rss/search?q=technology&hl=en-US&gl=US&ceid=US:en"
}

# %%
import pandas as pd

# The feed_urls dictionary
feed_urls = {
        "Top Stories": [
            {"rssFeedUrl":"https://feeds.feedburner.com/ndtvnews-top-stories", "source":"NDTV"},
            {"rssFeedUrl":"https://feeds.feedburner.com/ndtvnews-trending-news", "source":"NDTV"},
            {"rssFeedUrl":"https://frontline.thehindu.com/feeder/default.rss", "source":"The Hindu"},
            {"rssFeedUrl":"https://timesofindia.indiatimes.com/rssfeedstopstories.cms", "source":"Times of India"},
            {"rssFeedUrl":"https://timesofindia.indiatimes.com/rssfeedmostrecent.cms", "source":"Times of India"},
            {"rssFeedUrl":"https://economictimes.indiatimes.com/rssfeedstopstories.cms", "source":"Economic Times"},
            
            {"rssFeedUrl":"http://rss.cnn.com/rss/money_topstories.rss", "source":"CNN"},  
            {"rssFeedUrl":"http://rss.cnn.com/rss/money_mostpopular.rss", "source":"CNN"},
            {"rssFeedUrl":"https://www.aljazeera.com/xml/rss/all.xml", "source":"Al Jazeera"},
            {"rssFeedUrl":"https://feeds.bbci.co.uk/news/rss.xml", "source":"BBC"},
            {"rssFeedUrl":"https://news.google.com/rss/search?q=topstories&hl=en-US&gl=US&ceid=US:en", "source":"Google News"},
            {"rssFeedUrl":"https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=100003114", "source":"CNBC"}
        ],
        
        "Recent Stories":[
            {"rssFeedUrl":"https://frontline.thehindu.com/current-issue/feeder/default.rss", "source":"The Hindu"},
            {"rssFeedUrl":"https://feeds.feedburner.com/ndtvnews-latest", "source":"NDTV"},
            {"rssFeedUrl":"https://economictimes.indiatimes.com/rssfeedsdefault.cms", "source":"Economic Times"},
            {"rssFeedUrl":"https://economictimes.indiatimes.com/news/rssfeeds/1715249553.cms", "source":"Economic Times"},
            {"rssFeedUrl":"https://globalnews.ca/feed/", "source":"Global News"},
        ],

        "Technology": [
            {"rssFeedUrl":"https://frontline.thehindu.com/science-and-technology/feeder/default.rss", "source":"The Hindu"},
            {"rssFeedUrl":"https://feeds.feedburner.com/gadgets360-latest", "source":"NDTV"},
            {"rssFeedUrl":"https://timesofindia.indiatimes.com/rssfeeds/66949542.cms", "source":"Times of India"},  
            {"rssFeedUrl":"https://www.livemint.com/rss/technology", "source":"Mint"},
            {"rssFeedUrl":"https://economictimes.indiatimes.com/prime/technology-and-startups/rssfeeds/63319172.cms", "source":"Economic Times"},

            {"rssFeedUrl":"http://rss.cnn.com/rss/money_technology.rss", "source":"CNN"},
            {"rssFeedUrl":"https://feeds.bbci.co.uk/news/technology/rss.xml", "source":"BBC"},
            {"rssFeedUrl":"https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml", "source":"The New York Times"},
            {"rssFeedUrl":"https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=19854910", "source":"CNBC"},
        ],
        "Sports": [
            {"rssFeedUrl":"https://sportstar.thehindu.com/feeder/default.rss", "source":"The Hindu"},
            {"rssFeedUrl":"https://feeds.feedburner.com/ndtvsports-latest", "source":"NDTV"},
            {"rssFeedUrl":"https://www.espncricinfo.com/ci/content/rss/feeds_rss_cricket.html", "source":"ESPN"},
            {"rssFeedUrl":"https://economictimes.indiatimes.com/news/sports/rssfeeds/26407562.cms", "source":"Economic Times"},
            {"rssFeedUrl":"https://www.livemint.com/rss/sports", "source":"Mint"},
            {"rssFeedUrl":"https://timesofindia.indiatimes.com/rssfeeds/4719148.cms", "source":"Times of India"},

            {"rssFeedUrl":"https://rss.nytimes.com/services/xml/rss/nyt/Sports.xml", "source":"The New York Times"},
            {"rssFeedUrl":"https://globalnews.ca/sports/feed/", "source":"Global News"},
            {"rssFeedUrl":"https://api.foxsports.com/v2/content/optimized-rss?partnerKey=MB0Wehpmuj2lUhuRhQaafhBjAJqaPU244mlTDK1i&aggregateId=7f83e8ca-6701-5ea0-96ee-072636b67336", "source":"Fox Sports"},
        ],

        "Business": [
            {"rssFeedUrl":"https://frontline.thehindu.com/economy/feeder/default.rss", "source":"The Hindu"},
            {"rssFeedUrl":"https://feeds.feedburner.com/ndtvprofit-latest", "source":"NDTV"},
            {"rssFeedUrl":"https://timesofindia.indiatimes.com/rssfeeds/1898055.cms", "source":"Times of India"},
            {"rssFeedUrl":"https://www.livemint.com/rss/money", "source":"Mint"},
            {"rssFeedUrl":"https://economictimes.indiatimes.com/small-biz/rssfeeds/5575607.cms", "source":"Economic Times"},

            {"rssFeedUrl":"http://rss.cnn.com/rss/money_smbusiness.rss", "source":"CNN"},
            {"rssFeedUrl":"https://rss.nytimes.com/services/xml/rss/nyt/Business.xml", "source":"The New York Times"},
            {"rssFeedUrl":"https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10001147", "source":"CNBC"},
            {"rssFeedUrl":"https://globalnews.ca/money/feed/", "source":"Global News"},
        ],
        "Entertainment": [
            {"rssFeedUrl":"https://frontline.thehindu.com/arts-and-culture/feeder/default.rss", "source":"The Hindu"},
            {"rssFeedUrl":"https://feeds.feedburner.com/ndtvmovies-latest", "source":"NDTV"},
            {"rssFeedUrl":"https://timesofindia.indiatimes.com/rssfeeds/1081479906.cms", "source":"Times of India"},
            {"rssFeedUrl":"https://economictimes.indiatimes.com/industry/media/entertainment/rssfeeds/13357212.cms", "source":"Economic Times"},

            {"rssFeedUrl":"https://rss.nytimes.com/services/xml/rss/nyt/Movies.xml", "source":"The New York Times"},
            {"rssFeedUrl":"https://globalnews.ca/entertainment/feed/", "source":"Global News"},
            {"rssFeedUrl":"https://feeds.bbci.co.uk/news/entertainment_and_arts/rss.xml", "source":"BBC"},
        ],
        "Health":[
            {"rssFeedUrl":"https://frontline.thehindu.com/the-nation/public-health/feeder/default.rss", "source":"The Hindu"},
            {"rssFeedUrl":"https://feeds.feedburner.com/ndtvcooks-latest", "source":"NDTV"},
            {"rssFeedUrl":"https://timesofindia.indiatimes.com/rssfeeds/2886704.cms", "source":"Times of India"},
            {"rssFeedUrl":"https://economictimes.indiatimes.com/industry/healthcare/biotech/rssfeeds/13358050.cms", "source":"Economic Times"},
            

            {"rssFeedUrl":"https://rss.nytimes.com/services/xml/rss/nyt/Health.xml", "source":"The New York Times"},
            {"rssFeedUrl":"https://globalnews.ca/health/feed/", "source":"Global News"},
            {"rssFeedUrl":"https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml", "source":"United Nations"},
            {"rssFeedUrl":"https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000108", "source":"CNBC"},
            {"rssFeedUrl":"https://feeds.bbci.co.uk/news/health/rss.xml", "source":"BBC"},
        ],

        "Science":[
            {"rssFeedUrl":"https://frontline.thehindu.com/science-and-technology/feeder/default.rss", "source":"The Hindu"},
            {"rssFeedUrl":"https://timesofindia.indiatimes.com/rssfeeds/-2128672765.cms", "source":"Times of India"},
            {"rssFeedUrl":"https://livemint.com/rss/science", "source":"Mint"},
            {"rssFeedUrl":"https://economictimes.indiatimes.com/news/science/rssfeeds/39872847.cms", "source":"Economic Times"},
            
            {"rssFeedUrl":"https://rss.nytimes.com/services/xml/rss/nyt/Science.xml", "source":"The New York Times"},
            {"rssFeedUrl":"https://feeds.bbci.co.uk/news/science_and_environment/rss.xml", "source":"BBC"},
            
        ],
        
        "Finance":[
            {"rssFeedUrl":"https://frontline.thehindu.com/economy/feeder/default.rss", "source":"The Hindu"},
            {"rssFeedUrl":"https://www.livemint.com/rss/budget", "source":"Mint"},
            {"rssFeedUrl":"https://economictimes.indiatimes.com/industry/banking/finance/rssfeeds/13358259.cms", "source":"Economic Times"}
            ,
            {"rssFeedUrl":"http://rss.cnn.com/rss/money_pf.rss", "source":"CNN"},
            {"rssFeedUrl":"https://rss.nytimes.com/services/xml/rss/nyt/YourMoney.xml", "source":"The New York Times"},
            {"rssFeedUrl":"https://globalnews.ca/money/feed/", "source":"Global News"},
            {"rssFeedUrl":"https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000115", "source":"CNBC"},
        ],

        "Politics":[
            {"rssFeedUrl":"https://frontline.thehindu.com/politics/feeder/default.rss", "source":"The Hindu"},
            {"rssFeedUrl":"https://www.livemint.com/rss/elections", "source":"Mint"},
            {"rssFeedUrl":"https://economictimes.indiatimes.com/news/politics-and-nation/rssfeeds/1052732854.cms", "source":"Economic Times"},

            {"rssFeedUrl":"https://rss.nytimes.com/services/xml/rss/nyt/Politics.xml", "source":"The New York Times"},
            {"rssFeedUrl":"https://globalnews.ca/politics/feed/", "source":"Global News"},
            {"rssFeedUrl":"https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000113", "source":"CNBC"},
            {"rssFeedUrl":"https://feeds.bbci.co.uk/news/politics/rss.xml", "source":"BBC"},
        ],
        
        "Travel":[
            {"rssFeedUrl":"https://frontline.thehindu.com/other/travel/feeder/default.rss", "source":"The Hindu"},
            
            {"rssFeedUrl":"http://rss.cnn.com/rss/money_lifestyle.rss", "source":"CNN"},
            {"rssFeedUrl":"https://rss.nytimes.com/services/xml/rss/nyt/Travel.xml", "source":"The New York Times"},
            {"rssFeedUrl":"https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000739", "source":"CNBC"},
        ],

        "Education":[
            {"rssFeedUrl":"https://timesofindia.indiatimes.com/rssfeeds/913168846.cms", "source":"Times of India"},
            {"rssFeedUrl":"https://www.livemint.com/rss/education", "source":"Mint"},
            
            {"rssFeedUrl":"https://economictimes.indiatimes.com/nri/study/rssfeeds/79038794.cms", "source":"Economic Times"},
            {"rssFeedUrl":"https://rss.nytimes.com/services/xml/rss/nyt/Education.xml", "source":"The New York Times"},
            {"rssFeedUrl":"https://feeds.bbci.co.uk/news/education/rss.xml", "source":"BBC"},
        ]
    }




# Preparing data for conversion
data = []
for category, feeds in feed_urls.items():
    for feed in feeds:
        data.append({
            "Category": category,
            "RSS Feed URL": feed["rssFeedUrl"],
            "Source": feed["source"]
        })

# Convert the list of dictionaries to a pandas DataFrame
df = pd.DataFrame(data)

# Write the DataFrame to an Excel file
df.to_excel("rss_feed_urls.xlsx", index=False)

print("Excel file created successfully!")
# Out:
# Excel file created successfully!

# %%
df["Category"].unique()
df["Source"].unique()
df["RSS Feed URL"].unique()
# Out:
# array(['https://feeds.feedburner.com/ndtvnews-top-stories',
#        'https://feeds.feedburner.com/ndtvnews-trending-news',
#        'https://frontline.thehindu.com/feeder/default.rss',
#        'https://timesofindia.indiatimes.com/rssfeedstopstories.cms',
#        'https://timesofindia.indiatimes.com/rssfeedmostrecent.cms',
#        'https://economictimes.indiatimes.com/rssfeedstopstories.cms',
#        'http://rss.cnn.com/rss/money_topstories.rss',
#        'http://rss.cnn.com/rss/money_mostpopular.rss',
#        'https://www.aljazeera.com/xml/rss/all.xml',
#        'https://feeds.bbci.co.uk/news/rss.xml',
#        'https://news.google.com/rss/search?q=topstories&hl=en-US&gl=US&ceid=US:en',
#        'https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=100003114',
#        'https://frontline.thehindu.com/current-issue/feeder/default.rss',
#        'https://feeds.feedburner.com/ndtvnews-latest',
#        'https://economictimes.indiatimes.com/rssfeedsdefault.cms',
#        'https://economictimes.indiatimes.com/news/rssfeeds/1715249553.cms',
#        'https://globalnews.ca/feed/',
#        'https://frontline.thehindu.com/science-and-technology/feeder/default.rss',
#        'https://feeds.feedburner.com/gadgets360-latest',
#        'https://timesofindia.indiatimes.com/rssfeeds/66949542.cms',
#        'https://www.livemint.com/rss/technology',
#        'https://economictimes.indiatimes.com/prime/technology-and-startups/rssfeeds/63319172.cms',
#        'http://rss.cnn.com/rss/money_technology.rss',
#        'https://feeds.bbci.co.uk/news/technology/rss.xml',
#        'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#        'https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=19854910',
#        'https://sportstar.thehindu.com/feeder/default.rss',
#        'https://feeds.feedburner.com/ndtvsports-latest',
#        'https://www.espncricinfo.com/ci/content/rss/feeds_rss_cricket.html',
#        'https://economictimes.indiatimes.com/news/sports/rssfeeds/26407562.cms',
#        'https://www.livemint.com/rss/sports',
#        'https://timesofindia.indiatimes.com/rssfeeds/4719148.cms',
#        'https://rss.nytimes.com/services/xml/rss/nyt/Sports.xml',
#        'https://globalnews.ca/sports/feed/',
#        'https://api.foxsports.com/v2/content/optimized-rss?partnerKey=MB0Wehpmuj2lUhuRhQaafhBjAJqaPU244mlTDK1i&aggregateId=7f83e8ca-6701-5ea0-96ee-072636b67336',
#        'https://frontline.thehindu.com/economy/feeder/default.rss',
#        'https://feeds.feedburner.com/ndtvprofit-latest',
#        'https://timesofindia.indiatimes.com/rssfeeds/1898055.cms',
#        'https://www.livemint.com/rss/money',
#        'https://economictimes.indiatimes.com/small-biz/rssfeeds/5575607.cms',
#        'http://rss.cnn.com/rss/money_smbusiness.rss',
#        'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#        'https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10001147',
#        'https://globalnews.ca/money/feed/',
#        'https://frontline.thehindu.com/arts-and-culture/feeder/default.rss',
#        'https://feeds.feedburner.com/ndtvmovies-latest',
#        'https://timesofindia.indiatimes.com/rssfeeds/1081479906.cms',
#        'https://economictimes.indiatimes.com/industry/media/entertainment/rssfeeds/13357212.cms',
#        'https://rss.nytimes.com/services/xml/rss/nyt/Movies.xml',
#        'https://globalnews.ca/entertainment/feed/',
#        'https://feeds.bbci.co.uk/news/entertainment_and_arts/rss.xml',
#        'https://frontline.thehindu.com/the-nation/public-health/feeder/default.rss',
#        'https://feeds.feedburner.com/ndtvcooks-latest',
#        'https://timesofindia.indiatimes.com/rssfeeds/2886704.cms',
#        'https://economictimes.indiatimes.com/industry/healthcare/biotech/rssfeeds/13358050.cms',
#        'https://rss.nytimes.com/services/xml/rss/nyt/Health.xml',
#        'https://globalnews.ca/health/feed/',
#        'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml',
#        'https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000108',
#        'https://feeds.bbci.co.uk/news/health/rss.xml',
#        'https://timesofindia.indiatimes.com/rssfeeds/-2128672765.cms',
#        'https://livemint.com/rss/science',
#        'https://economictimes.indiatimes.com/news/science/rssfeeds/39872847.cms',
#        'https://rss.nytimes.com/services/xml/rss/nyt/Science.xml',
#        'https://feeds.bbci.co.uk/news/science_and_environment/rss.xml',
#        'https://www.livemint.com/rss/budget',
#        'https://economictimes.indiatimes.com/industry/banking/finance/rssfeeds/13358259.cms',
#        'http://rss.cnn.com/rss/money_pf.rss',
#        'https://rss.nytimes.com/services/xml/rss/nyt/YourMoney.xml',
#        'https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000115',
#        'https://frontline.thehindu.com/politics/feeder/default.rss',
#        'https://www.livemint.com/rss/elections',
#        'https://economictimes.indiatimes.com/news/politics-and-nation/rssfeeds/1052732854.cms',
#        'https://rss.nytimes.com/services/xml/rss/nyt/Politics.xml',
#        'https://globalnews.ca/politics/feed/',
#        'https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000113',
#        'https://feeds.bbci.co.uk/news/politics/rss.xml',
#        'https://frontline.thehindu.com/other/travel/feeder/default.rss',
#        'http://rss.cnn.com/rss/money_lifestyle.rss',
#        'https://rss.nytimes.com/services/xml/rss/nyt/Travel.xml',
#        'https://search.cnbc.com/rs/search/combinedcms/view.xml?partnerId=wrss01&id=10000739',
#        'https://timesofindia.indiatimes.com/rssfeeds/913168846.cms',
#        'https://www.livemint.com/rss/education',
#        'https://economictimes.indiatimes.com/nri/study/rssfeeds/79038794.cms',
#        'https://rss.nytimes.com/services/xml/rss/nyt/Education.xml',
#        'https://feeds.bbci.co.uk/news/education/rss.xml'], dtype=object)

# %%
import pandas as pd

# Assuming df is your DataFrame
pivot_df = df.pivot_table(index='Source', columns='Category',values='RSS Feed URL', aggfunc='size', fill_value=0)
pivot_df
# Out:
# Category            Business  Education  Entertainment  Finance  Health  \
# Source
# Al Jazeera                 0          0              0        0       0
# BBC                        0          1              1        0       1
# CNBC                       1          0              0        1       1
# CNN                        1          0              0        1       0
# ESPN                       0          0              0        0       0
# Economic Times             1          1              1        1       1
# Fox Sports                 0          0              0        0       0
# Global News                1          0              1        1       1
# Google News                0          0              0        0       0
# Mint                       1          1              0        1       0
# NDTV                       1          0              1        0       1
# The Hindu                  1          0              1        1       1
# The New York Times         1          1              1        1       1
# Times of India             1          1              1        0       1
# United Nations             0          0              0        0       1
#
# Category            Politics  Recent Stories  Science  Sports  Technology  \
# Source
# Al Jazeera                 0               0        0       0           0
# BBC                        1               0        1       0           1
# CNBC                       1               0        0       0           1
# CNN                        0               0        0       0           1
# ESPN                       0               0        0       1           0
# Economic Times             1               2        1       1           1
# Fox Sports                 0               0        0       1           0
# Global News                1               1        0       1           0
# Google News                0               0        0       0           0
# Mint                       1               0        1       1           1
# NDTV                       0               1        0       1           1
# The Hindu                  1               1        1       1           1
# The New York Times         1               0        1       1           1
# Times of India             0               0        1       1           1
# United Nations             0               0        0       0           0
#
# Category            Top Stories  Travel
# Source
# Al Jazeera                    1       0
# BBC                           1       0
# CNBC                          1       1
# CNN                           2       1
# ESPN                          0       0
# Economic Times                1       0
# Fox Sports                    0       0
# Global News                   0       0
# Google News                   1       0
# Mint                          0       0
# NDTV                          2       0
# The Hindu                     1       1
# The New York Times            0       1
# Times of India                2       0
# United Nations                0       0

# %%
import pandas as pd

# Assuming df has 'Source', 'Category', and 'RSS_feed' columns

# Create a custom aggregation function to join RSS feeds
pivot_df = df.pivot_table(index='Source', columns='Category', values='RSS Feed URL', aggfunc=lambda x: ', '.join(x))

# Reset the index to make 'Source' a column
pivot_df = pivot_df.reset_index()

# Now, when you export it, 'Source' will be a regular column
pivot_df.to_excel('rss_feed_urls.xlsx', index=False)

pivot_df
# Out:
# Category              Source  \
# 0                 Al Jazeera
# 1                        BBC
# 2                       CNBC
# 3                        CNN
# 4                       ESPN
# 5             Economic Times
# 6                 Fox Sports
# 7                Global News
# 8                Google News
# 9                       Mint
# 10                      NDTV
# 11                 The Hindu
# 12        The New York Times
# 13            Times of India
# 14            United Nations
#
# Category                                           Business  \
# 0                                                       NaN
# 1                                                       NaN
# 2         https://search.cnbc.com/rs/search/combinedcms/...
# 3               http://rss.cnn.com/rss/money_smbusiness.rss
# 4                                                       NaN
# 5         https://economictimes.indiatimes.com/small-biz...
# 6                                                       NaN
# 7                         https://globalnews.ca/money/feed/
# 8                                                       NaN
# 9                        https://www.livemint.com/rss/money
# 10           https://feeds.feedburner.com/ndtvprofit-latest
# 11        https://frontline.thehindu.com/economy/feeder/...
# 12        https://rss.nytimes.com/services/xml/rss/nyt/B...
# 13        https://timesofindia.indiatimes.com/rssfeeds/1...
# 14                                                      NaN
#
# Category                                          Education  \
# 0                                                       NaN
# 1           https://feeds.bbci.co.uk/news/education/rss.xml
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# 5         https://economictimes.indiatimes.com/nri/study...
# 6                                                       NaN
# 7                                                       NaN
# 8                                                       NaN
# 9                    https://www.livemint.com/rss/education
# 10                                                      NaN
# 11                                                      NaN
# 12        https://rss.nytimes.com/services/xml/rss/nyt/E...
# 13        https://timesofindia.indiatimes.com/rssfeeds/9...
# 14                                                      NaN
#
# Category                                      Entertainment  \
# 0                                                       NaN
# 1         https://feeds.bbci.co.uk/news/entertainment_an...
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# 5         https://economictimes.indiatimes.com/industry/...
# 6                                                       NaN
# 7                 https://globalnews.ca/entertainment/feed/
# 8                                                       NaN
# 9                                                       NaN
# 10           https://feeds.feedburner.com/ndtvmovies-latest
# 11        https://frontline.thehindu.com/arts-and-cultur...
# 12        https://rss.nytimes.com/services/xml/rss/nyt/M...
# 13        https://timesofindia.indiatimes.com/rssfeeds/1...
# 14                                                      NaN
#
# Category                                            Finance  \
# 0                                                       NaN
# 1                                                       NaN
# 2         https://search.cnbc.com/rs/search/combinedcms/...
# 3                       http://rss.cnn.com/rss/money_pf.rss
# 4                                                       NaN
# 5         https://economictimes.indiatimes.com/industry/...
# 6                                                       NaN
# 7                         https://globalnews.ca/money/feed/
# 8                                                       NaN
# 9                       https://www.livemint.com/rss/budget
# 10                                                      NaN
# 11        https://frontline.thehindu.com/economy/feeder/...
# 12        https://rss.nytimes.com/services/xml/rss/nyt/Y...
# 13                                                      NaN
# 14                                                      NaN
#
# Category                                             Health  \
# 0                                                       NaN
# 1              https://feeds.bbci.co.uk/news/health/rss.xml
# 2         https://search.cnbc.com/rs/search/combinedcms/...
# 3                                                       NaN
# 4                                                       NaN
# 5         https://economictimes.indiatimes.com/industry/...
# 6                                                       NaN
# 7                        https://globalnews.ca/health/feed/
# 8                                                       NaN
# 9                                                       NaN
# 10            https://feeds.feedburner.com/ndtvcooks-latest
# 11        https://frontline.thehindu.com/the-nation/publ...
# 12        https://rss.nytimes.com/services/xml/rss/nyt/H...
# 13        https://timesofindia.indiatimes.com/rssfeeds/2...
# 14        https://news.un.org/feed/subscribe/en/news/top...
#
# Category                                           Politics  \
# 0                                                       NaN
# 1            https://feeds.bbci.co.uk/news/politics/rss.xml
# 2         https://search.cnbc.com/rs/search/combinedcms/...
# 3                                                       NaN
# 4                                                       NaN
# 5         https://economictimes.indiatimes.com/news/poli...
# 6                                                       NaN
# 7                      https://globalnews.ca/politics/feed/
# 8                                                       NaN
# 9                    https://www.livemint.com/rss/elections
# 10                                                      NaN
# 11        https://frontline.thehindu.com/politics/feeder...
# 12        https://rss.nytimes.com/services/xml/rss/nyt/P...
# 13                                                      NaN
# 14                                                      NaN
#
# Category                                     Recent Stories  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# 5         https://economictimes.indiatimes.com/rssfeedsd...
# 6                                                       NaN
# 7                               https://globalnews.ca/feed/
# 8                                                       NaN
# 9                                                       NaN
# 10             https://feeds.feedburner.com/ndtvnews-latest
# 11        https://frontline.thehindu.com/current-issue/f...
# 12                                                      NaN
# 13                                                      NaN
# 14                                                      NaN
#
# Category                                            Science  \
# 0                                                       NaN
# 1         https://feeds.bbci.co.uk/news/science_and_envi...
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# 5         https://economictimes.indiatimes.com/news/scie...
# 6                                                       NaN
# 7                                                       NaN
# 8                                                       NaN
# 9                          https://livemint.com/rss/science
# 10                                                      NaN
# 11        https://frontline.thehindu.com/science-and-tec...
# 12        https://rss.nytimes.com/services/xml/rss/nyt/S...
# 13        https://timesofindia.indiatimes.com/rssfeeds/-...
# 14                                                      NaN
#
# Category                                             Sports  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4         https://www.espncricinfo.com/ci/content/rss/fe...
# 5         https://economictimes.indiatimes.com/news/spor...
# 6         https://api.foxsports.com/v2/content/optimized...
# 7                        https://globalnews.ca/sports/feed/
# 8                                                       NaN
# 9                       https://www.livemint.com/rss/sports
# 10           https://feeds.feedburner.com/ndtvsports-latest
# 11        https://sportstar.thehindu.com/feeder/default.rss
# 12        https://rss.nytimes.com/services/xml/rss/nyt/S...
# 13        https://timesofindia.indiatimes.com/rssfeeds/4...
# 14                                                      NaN
#
# Category                                         Technology  \
# 0                                                       NaN
# 1          https://feeds.bbci.co.uk/news/technology/rss.xml
# 2         https://search.cnbc.com/rs/search/combinedcms/...
# 3               http://rss.cnn.com/rss/money_technology.rss
# 4                                                       NaN
# 5         https://economictimes.indiatimes.com/prime/tec...
# 6                                                       NaN
# 7                                                       NaN
# 8                                                       NaN
# 9                   https://www.livemint.com/rss/technology
# 10           https://feeds.feedburner.com/gadgets360-latest
# 11        https://frontline.thehindu.com/science-and-tec...
# 12        https://rss.nytimes.com/services/xml/rss/nyt/T...
# 13        https://timesofindia.indiatimes.com/rssfeeds/6...
# 14                                                      NaN
#
# Category                                        Top Stories  \
# 0                 https://www.aljazeera.com/xml/rss/all.xml
# 1                     https://feeds.bbci.co.uk/news/rss.xml
# 2         https://search.cnbc.com/rs/search/combinedcms/...
# 3         http://rss.cnn.com/rss/money_topstories.rss, h...
# 4                                                       NaN
# 5         https://economictimes.indiatimes.com/rssfeedst...
# 6                                                       NaN
# 7                                                       NaN
# 8         https://news.google.com/rss/search?q=topstorie...
# 9                                                       NaN
# 10        https://feeds.feedburner.com/ndtvnews-top-stor...
# 11        https://frontline.thehindu.com/feeder/default.rss
# 12                                                      NaN
# 13        https://timesofindia.indiatimes.com/rssfeedsto...
# 14                                                      NaN
#
# Category                                             Travel
# 0                                                       NaN
# 1                                                       NaN
# 2         https://search.cnbc.com/rs/search/combinedcms/...
# 3                http://rss.cnn.com/rss/money_lifestyle.rss
# 4                                                       NaN
# 5                                                       NaN
# 6                                                       NaN
# 7                                                       NaN
# 8                                                       NaN
# 9                                                       NaN
# 10                                                      NaN
# 11        https://frontline.thehindu.com/other/travel/fe...
# 12        https://rss.nytimes.com/services/xml/rss/nyt/T...
# 13                                                      NaN
# 14                                                      NaN

# %%
# Write the DataFrame to an Excel file
pivot_df.to_csv("rss_feed_urls.csv", index=False)
